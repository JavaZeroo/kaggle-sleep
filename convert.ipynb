# %%
import torch

# %%
ckpt = torch.load('output/train/exp035/single/child-mind-institute-detect-sleep-states/5cakvuw9/checkpoints/epoch=27-step=5320.ckpt')

# %%
# pt = torch.load('output/train/exp031/single/best_model.pth')

# %%
ckpt['state_dict'].keys()
ret={}
for k,v in ckpt['state_dict'].items():
    ret[k.replace("model.", "", 1)] = v

# %%
# pt.keys()
# Out:
# odict_keys(['feature_extractor.cnn_feature_extractor.spec_conv.0.weight', 'feature_extractor.cnn_feature_extractor.spec_conv.0.bias', 'feature_extractor.cnn_feature_extractor.spec_conv.1.weight', 'feature_extractor.cnn_feature_extractor.spec_conv.1.bias', 'feature_extractor.cnn_feature_extractor.spec_conv.2.weight', 'feature_extractor.cnn_feature_extractor.spec_conv.2.bias', 'feature_extractor.cnn_feature_extractor.spec_conv.3.weight', 'feature_extractor.cnn_feature_extractor.spec_conv.3.bias', 'feature_extractor.cnn_feature_extractor.spec_conv.4.weight', 'feature_extractor.cnn_feature_extractor.spec_conv.4.bias', 'feature_extractor.spec_feature_extractor.feature_extractor.0.window', 'encoder.encoder._conv_stem.weight', 'encoder.encoder._bn0.weight', 'encoder.encoder._bn0.bias', 'encoder.encoder._bn0.running_mean', 'encoder.encoder._bn0.running_var', 'encoder.encoder._bn0.num_batches_tracked', 'encoder.encoder._blocks.0._depthwise_conv.weight', 'encoder.encoder._blocks.0._bn1.weight'
# ...

# %%
torch.save(ret, 'output/train/exp036/single/best_model.pth')
